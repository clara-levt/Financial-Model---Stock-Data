# %%
import numpy as np
import pandas as pd
from pandas_datareader import data
import yfinance as yf 
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import date

# %%
# update code to use yfinance with padas_datareader
# code update for 2023: https://github.com/ranaroussi/yfinance
yf.pdr_override() # <== that's all it takes

# %%
#VHYL and SDGPEX are nominated in Euro
stock_list = ['VHYL.AS','SDGPEX.SW','DVYA','DVYE','IVV']
start_date = '2017-01-01'
end_date = date.today()

# %%
df = data.get_data_yahoo(stock_list, data_source = 'yahoo', start=start_date, end=end_date)
df.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
#             Adj Close                                                   Close  \
#                  DVYA       DVYE         IVV  SDGPEX.SW    VHYL.AS       DVYA
# Date
# 2017-01-02        NaN        NaN         NaN        NaN  48.400002        NaN
# 2017-01-03  32.767242  23.664062  203.194916  28.719999  48.650002  45.680000
# 2017-01-04  33.125896  23.867529  204.423553  28.719999  48.709999  46.180000
# 2017-01-05  33.484550  24.064228  204.235229  28.719999  48.389999  46.680000
# 2017-01-06  33.362606  23.908220  205.042313  28.500000  48.500000  46.509998
#
#                                                          ...       Open  \
#                  DVYE         IVV  SDGPEX.SW    VHYL.AS  ...       DVYA
# Date                                                     ...
# 2017-01-02        NaN         NaN        NaN  48.400002  ...        NaN
# 2017-01-03  34.889999  226.580002  28.719999  48.650002  ...  45.770000
# 2017-01-04  35.189999  227.949997  28.719999  48.709999  ...  46.060001
# 2017-01-05  35.480000  227.740005  28.719999  48.389999  ...  46.730000
# 2017-01-06  35.250000  228.639999  28.500000  48.500000  ...  46.630001
#
#                                                           Volume            \
#                  DVYE         IVV  SDGPEX.SW    VHYL.AS     DVYA      DVYE
# Date
# 2017-01-02        NaN         NaN        NaN  47.950001      NaN       NaN
# 2017-01-03  34.860001  226.399994  28.719999  48.500000  41900.0   74200.0
# 2017-01-04  35.060001  226.960007  28.719999  48.740002   6100.0   87300.0
# 2017-01-05  35.340000  227.630005  28.719999  48.540001   2300.0  105700.0
# 2017-01-06  35.369999  227.910004  28.500000  48.430000   4200.0   30700.0
#
#
#                   IVV SDGPEX.SW  VHYL.AS
# Date
# 2017-01-02        NaN       NaN  18197.0
# 2017-01-03  6396600.0     100.0  15319.0
# 2017-01-04  4099000.0      34.0  15805.0
# 2017-01-05  2970100.0       0.0  18923.0
# 2017-01-06  3110100.0     180.0   9114.0
#
# [5 rows x 30 columns]

# %%
# Closing price
df = df['Adj Close']
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1504 entries, 2017-01-03 to 2023-02-17
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DVYA       1504 non-null   float64
#  1   DVYE       1504 non-null   float64
#  2   IVV        1504 non-null   float64
#  3   SDGPEX.SW  1504 non-null   float64
#  4   VHYL.AS    1504 non-null   float64
# dtypes: float64(5)
# memory usage: 70.5 KB

# %%
euro_usd = data.get_data_yahoo('EURUSD=X', data_source = 'yahoo', start=start_date, end=end_date)
euro_usd.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-01-02  1.053075  1.054074  1.046572  1.052698   1.052698       0
# 2017-01-03  1.045916  1.049208  1.034768  1.046003   1.046003       0
# 2017-01-04  1.041840  1.047889  1.039134  1.041992   1.041992       0
# 2017-01-05  1.049869  1.060895  1.048658  1.050089   1.050089       0
# 2017-01-06  1.060558  1.060895  1.053963  1.060592   1.060592       0

# %%
dvya_div = pd.read_csv('vhya_dividend.csv', parse_dates = [0], index_col = 0)
dvye_div = pd.read_csv('dvye_dividend.csv', parse_dates = [0], index_col = 0)
vhya_div = pd.read_csv('vhya_dividend.csv', parse_dates = [0], index_col = 0) #dividend is in cent USD
SDGPEX_div = pd.read_csv('SDGPEX_dividend.csv', parse_dates = [0], index_col = 0)

# %%
euro_usd_close = euro_usd[['Close']]

# %%
euro_usd_close.head()
# Out:
#                Close
# Date
# 2017-01-02  1.052698
# 2017-01-03  1.046003
# 2017-01-04  1.041992
# 2017-01-05  1.050089
# 2017-01-06  1.060592

# %%
joined_df = df.join([euro_usd_close,dvye_div, vhya_div,SDGPEX_div])
joined_df.head()
# Out:
#                  DVYA       DVYE         IVV  SDGPEX.SW    VHYL.AS     Close  \
# Date
# 2017-01-03  32.767242  23.664062  203.194916  28.719999  48.650002  1.046003
# 2017-01-04  33.125896  23.867529  204.423553  28.719999  48.709999  1.041992
# 2017-01-05  33.484550  24.064228  204.235229  28.719999  48.389999  1.050089
# 2017-01-06  33.362606  23.908220  205.042313  28.500000  48.500000  1.060592
# 2017-01-09  33.534771  23.860744  204.378708  28.500000  48.310001  1.053186
#
#             DVYE_div  Unnamed: 2  VHYA_div  SDGPEX_DE_div
# Date
# 2017-01-03       0.0         NaN       NaN            NaN
# 2017-01-04       0.0         NaN       NaN            NaN
# 2017-01-05       0.0         NaN       NaN            NaN
# 2017-01-06       0.0         NaN       NaN            NaN
# 2017-01-09       0.0         NaN       NaN            NaN

# %%
joined_df=joined_df.fillna(0)
joined_df.head()
# Out:
#                  DVYA       DVYE         IVV  SDGPEX.SW    VHYL.AS     Close  \
# Date
# 2017-01-03  32.767242  23.664062  203.194916  28.719999  48.650002  1.046003
# 2017-01-04  33.125896  23.867529  204.423553  28.719999  48.709999  1.041992
# 2017-01-05  33.484550  24.064228  204.235229  28.719999  48.389999  1.050089
# 2017-01-06  33.362606  23.908220  205.042313  28.500000  48.500000  1.060592
# 2017-01-09  33.534771  23.860744  204.378708  28.500000  48.310001  1.053186
#
#             DVYE_div  Unnamed: 2  VHYA_div  SDGPEX_DE_div
# Date
# 2017-01-03       0.0         0.0       0.0            0.0
# 2017-01-04       0.0         0.0       0.0            0.0
# 2017-01-05       0.0         0.0       0.0            0.0
# 2017-01-06       0.0         0.0       0.0            0.0
# 2017-01-09       0.0         0.0       0.0            0.0

# %%
joined_df['DVYA'] = joined_df['DVYA'] + joined_df['Unnamed: 2']
joined_df['DVYE'] = joined_df['DVYE'] + joined_df['DVYE_div']
joined_df['SDGPEX_usd'] = (joined_df['SDGPEX.SW'] + joined_df['SDGPEX_DE_div'])*joined_df['Close']
joined_df['VHY_usd'] = joined_df['VHYL.AS'] *joined_df['Close'] + joined_df['VHYA_div']*0.01
joined_df.head()
# Out:
#                  DVYA       DVYE         IVV  SDGPEX.SW    VHYL.AS     Close  \
# Date
# 2017-01-03  32.767242  23.664062  203.194916  28.719999  48.650002  1.046003
# 2017-01-04  33.125896  23.867529  204.423553  28.719999  48.709999  1.041992
# 2017-01-05  33.484550  24.064228  204.235229  28.719999  48.389999  1.050089
# 2017-01-06  33.362606  23.908220  205.042313  28.500000  48.500000  1.060592
# 2017-01-09  33.534771  23.860744  204.378708  28.500000  48.310001  1.053186
#
#             DVYE_div  Unnamed: 2  VHYA_div  SDGPEX_DE_div  SDGPEX_usd  \
# Date
# 2017-01-03       0.0         0.0       0.0            0.0   30.041212
# 2017-01-04       0.0         0.0       0.0            0.0   29.926018
# 2017-01-05       0.0         0.0       0.0            0.0   30.158562
# 2017-01-06       0.0         0.0       0.0            0.0   30.226860
# 2017-01-09       0.0         0.0       0.0            0.0   30.015796
#
#               VHY_usd
# Date
# 2017-01-03  50.888058
# 2017-01-04  50.755444
# 2017-01-05  50.813818
# 2017-01-06  51.438692
# 2017-01-09  50.879408

# %%
df_usd = joined_df[['DVYA','DVYE','SDGPEX_usd','VHY_usd','IVV']]
df_usd.head()
# Out:
#                  DVYA       DVYE  SDGPEX_usd    VHY_usd         IVV
# Date
# 2017-01-03  32.767242  23.664062   30.041212  50.888058  203.194916
# 2017-01-04  33.125896  23.867529   29.926018  50.755444  204.423553
# 2017-01-05  33.484550  24.064228   30.158562  50.813818  204.235229
# 2017-01-06  33.362606  23.908220   30.226860  51.438692  205.042313
# 2017-01-09  33.534771  23.860744   30.015796  50.879408  204.378708

# %%
growth_df = df_usd.apply(lambda x: x.div(x.iloc[0]).subtract(1).mul(100))
growth_df.head()
# Out:
#                 DVYA      DVYE  SDGPEX_usd   VHY_usd       IVV
# Date
# 2017-01-03  0.000000  0.000000    0.000000  0.000000  0.000000
# 2017-01-04  1.094551  0.859812   -0.383452 -0.260600  0.604660
# 2017-01-05  2.189101  1.691026    0.390631 -0.145890  0.511978
# 2017-01-06  1.816948  1.031766    0.617978  1.082048  0.909175
# 2017-01-09  2.342365  0.831142   -0.084604 -0.016998  0.582589

# %%
growth_df.tail()
# Out:
#                 DVYA      DVYE  SDGPEX_usd    VHY_usd         IVV
# Date
# 2023-02-13  8.217831  6.575104    3.964895  19.175730  104.129123
# 2023-02-14  8.156793  6.532845    4.835254  19.770300  104.020852
# 2023-02-15  7.210734  6.237039    4.297377  20.027771  104.670478
# 2023-02-16  7.485399  6.532845    3.905878  19.309350  101.914500
# 2023-02-17  7.393836  6.575104    3.919475  18.744640  101.353470

# %%
plt.figure(figsize=(12,8))
plt.plot(growth_df*1000) #Started with $1000 for each ETF
plt.legend(growth_df)
plt.show()

# %% [markdown]
# ## Sharp ratio Portfolio

# %%
log_ret = np.log(df_usd/df_usd.shift(1))
log_ret.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
np.random.seed(123)
num_ports = 5000
all_weights = np.zeros((num_ports, len(df_usd.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)
rf = 0.04 #risk-free rate of treasury bond
for x in range(num_ports):
    # Weights
    weights = np.array(np.random.random(len(df_usd.columns))) #number of random weight equal number of tickers
    weights = weights/np.sum(weights)
    
    # Save weights
    all_weights[x,:] = weights
    
    # Expected return
    ret_arr[x] = np.sum( (log_ret.mean() * weights * 252)) #crypto trading is 365 days/year, stock trading 252 days/year
    
    # Expected volatility
    vol_arr[x] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov()*252, weights)))
    
    # Sharpe Ratio
    sharpe_arr[x] = (ret_arr[x]-rf)/vol_arr[x]

# %%
print('Max Sharpe ratio in the array: {}'.format(sharpe_arr.max()))

#numpy.argmax Returns the indices of the maximum values along an axis.

print('Index of max Sharpe ratio in the array: {}'.format(sharpe_arr.argmax()))
# Out:
# Max Sharpe ratio in the array: 0.11348704279462891
# Index of max Sharpe ratio in the array: 2720

# %%
print('Max Sharpe ratio allocation: {}'.format(all_weights[sharpe_arr.argmax(),:]))
# Out:
# Max Sharpe ratio allocation: [0.164709   0.00230184 0.00869795 0.17374633 0.65054489]

# %%
#print expected return of max sharpe ratio
max_sr_ret = ret_arr[sharpe_arr.argmax()]
print('Return of portfolio with highest Sharpe ratio: {}'.format(max_sr_ret))
# Print expected volatility of portfolio with highest Sharpe ratio
max_sr_vol = vol_arr[sharpe_arr.argmax()]
print('Volatility of portfolio with highest Sharpe ratio: {}'.format(max_sr_vol))
# Out:
# Return of portfolio with highest Sharpe ratio: 0.06192174193339401
# Volatility of portfolio with highest Sharpe ratio: 0.19316515254578046

# %%
#print expected return of minimum volatility
min_vol_ret = ret_arr[vol_arr.argmin()]
print('Return of portfolio with : {}'.format(min_vol_ret))
# Print miminum volatility
min_vol = vol_arr.min()
print('Lowest volatility: {}'.format(min_vol))
# Out:
# Return of portfolio with : 0.01159707879555313
# Lowest volatility: 0.1651840827970929

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.scatter(max_sr_vol, max_sr_ret,c='red', s=50) # red dot
plt.scatter(min_vol, min_vol_ret,c='black', s=50) # black dot
plt.show()
